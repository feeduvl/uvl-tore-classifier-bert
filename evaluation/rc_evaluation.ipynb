# %%
import mlflow
from mlflow.entities import ViewType
from IPython.display import Image
from PIL import Image
import matplotlib.pyplot as plt
import ast
import pandas as pd

# %%
mlflow.get_registry_uri()
# Out:
# 'http://127.0.0.1:5000'

# %%
def getRunMetricsAndArtifacts(experimentName: str, runName: str):
    
    experiment = mlflow.get_experiment_by_name(experimentName)
    experiment_id = experiment.experiment_id
    
    run = mlflow.search_runs(experiment_ids=[experiment_id], filter_string=f"tags.mlflow.runName = '{runName}'")
    runID = run.iloc[0]['run_id']
    run_info = mlflow.get_run(runID)
    
    path = mlflow.artifacts.download_artifacts(
        run_id=runID, artifact_path="confusion_matrix.png"
    )

    metrics = run_info.data.metrics

    mean_precision = metrics.get('mean_precision')
    mean_recall = metrics.get('mean_recall')
    mean_f1 = metrics.get('mean_f1')
    
    return path, mean_precision, mean_recall, mean_f1

# %%
originalPathLevels, original_mean_precision_levels, original_mean_recall_levels, original_mean_f1_levels = getRunMetricsAndArtifacts("ORIGINAL_LEVELS", "original_levels")
originalPathCategories, original_mean_precision_categories, original_mean_recall_categories, original_mean_f1_categories = getRunMetricsAndArtifacts("ORIGINAL_CATEGORIES", "original_categories")
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Performance Comparison BERT with vs. without Relevance Dataset

# %% [markdown]
# ## BERT First Stage (TORE Levels)

# %%
relevancePath, relevance_mean_precision, relevance_mean_recall, relevance_mean_f1 = getRunMetricsAndArtifacts("RC_LEVELS", "rc_levels")

relevance_image = Image.open(relevancePath)
original_image = Image.open(originalPathLevels)

plt.figure(figsize=(12, 6))

# Plot original
plt.subplot(1,2,1)
plt.imshow(original_image)
plt.title("Original BERT First Stage")

# Plot relevance
plt.subplot(1,2,2)
plt.imshow(relevance_image)
plt.title("Relevance BERT First Stage")

plt.show
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = {
    'Run': ['RC_LEVELS', 'ORIGINAL_LEVELS'],
    'Mean Precision': [relevance_mean_precision, original_mean_precision_levels],
    'Mean Recall': [relevance_mean_recall, original_mean_recall_levels],
    'Mean F1': [relevance_mean_f1, original_mean_f1_levels]
}

df = pd.DataFrame(data)
df
# Out:
#                Run  Mean Precision  Mean Recall   Mean F1
# 0        RC_LEVELS        0.814706     0.793715  0.804051
# 1  ORIGINAL_LEVELS        0.818994     0.792133  0.805312

# %% [markdown]
# ## BERT E2E (TORE Categories)

# %%
relevancePath, relevance_mean_precision, relevance_mean_recall, relevance_mean_f1 = getRunMetricsAndArtifacts("RC_CATEGORIES", "rc_categories")

relevance_image = Image.open(relevancePath)
original_image = Image.open(originalPathCategories)

plt.figure(figsize=(12, 6))

# Plot original
plt.subplot(1,2,1)
plt.imshow(original_image)
plt.title("Original BERT E2E")

# Plot relevance
plt.subplot(1,2,2)
plt.imshow(relevance_image)
plt.title("Relevance BERT E2E")

plt.show
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = {
    'Run': ['RC_CATEGORIES', 'ORIGINAL_CATEGORIES'],
    'Mean Precision': [relevance_mean_precision, original_mean_precision_categories],
    'Mean Recall': [relevance_mean_recall, original_mean_recall_categories],
    'Mean F1': [relevance_mean_f1, original_mean_f1_categories]
}

df = pd.DataFrame(data)
df
# Out:
#                    Run  Mean Precision  Mean Recall   Mean F1
# 0        RC_CATEGORIES        0.676868     0.632285  0.653787
# 1  ORIGINAL_CATEGORIES        0.670642     0.634695  0.652106
